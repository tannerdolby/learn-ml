# %%
import pandas as pd
import os

# A dataframe is kind of like a Python nested list but it is pandas way
# of representing tabular data

# Create a dataframe for the global education CSV data
dataset_path = os.path.join(os.getcwd(), "..", "..", "data/Global_Education.csv")
df = pd.read_csv(dataset_path, encoding='latin1')
# Replace empty spaces with underscores in column names
df.columns = [column.lower().strip().replace(' ', '_') for column in df.columns]

# %%
df.head()
# Out:
#   countries_and_areas   latitude  longitude  oosr_pre0primary_age_male  \
# 0         Afghanistan  33.939110  67.709953                          0
# 1             Albania  41.153332  20.168331                          4
# 2             Algeria  28.033886   1.659626                          0
# 3             Andorra  42.506285   1.521801                          0
# 4              Angola  11.202692  17.873887                         31
#
#    oosr_pre0primary_age_female  oosr_primary_age_male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    oosr_primary_age_female  oosr_lower_secondary_age_male  \
# 0                        0                              0
# 1                        3                              6
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  oosr_pre0primary_age_male  \
# count  202.000000  202.000000                 202.000000
# mean    25.081422   55.166928                  19.658416
# std     16.813639   45.976287                  25.007604
# min      0.023559    0.824782                   0.000000
# 25%     11.685062   18.665678                   0.000000
# 50%     21.207861   43.518091                   9.000000
# 75%     39.901792   77.684945                  31.000000
# max     64.963051  178.065032                  96.000000
#
#        oosr_pre0primary_age_female  oosr_primary_age_male  \
# count                   202.000000             202.000000
# mean                     19.282178               5.282178
# std                      25.171147               9.396442
# min                       0.000000               0.000000
# 25%                       0.000000               0.000000
# 50%                       7.000000               1.000000
# ...

# %%
df['latitude']
# Out:
# 0      33.939110
# 1      41.153332
# 2      28.033886
# 3      42.506285
# 4      11.202692
#          ...
# 197     6.423750
# 198    14.058324
# 199    15.552727
# 200    13.133897
# 201    19.015438
# Name: latitude, Length: 202, dtype: float64

# %%
df.columns
# Out:
# Index(['countries_and_areas', 'latitude', 'longitude',
#        'oosr_pre0primary_age_male', 'oosr_pre0primary_age_female',
#        'oosr_primary_age_male', 'oosr_primary_age_female',
#        'oosr_lower_secondary_age_male', 'oosr_lower_secondary_age_female',
#        'oosr_upper_secondary_age_male', 'oosr_upper_secondary_age_female',
#        'completion_rate_primary_male', 'completion_rate_primary_female',
#        'completion_rate_lower_secondary_male',
#        'completion_rate_lower_secondary_female',
#        'completion_rate_upper_secondary_male',
#        'completion_rate_upper_secondary_female',
#        'grade_2_3_proficiency_reading', 'grade_2_3_proficiency_math',
#        'primary_end_proficiency_reading', 'primary_end_proficiency_math',
#        'lower_secondary_end_proficiency_reading',
#        'lower_secondary_end_proficiency_math',
#        'youth_15_24_literacy_rate_male', 'youth_15_24_literacy_rate_female',
# ...

# %%
# Can also use a complex mapper function or lambda to rename the columns
def clean_column(col):
    return col.lower().strip().replace(' ', '_')

df_clean = df.rename(clean_column, axis='columns')
df_clean_two = df.rename(lambda col: col.lower().strip().replace(' ', '_'), axis='columns')

# %%
df_clean.head()
# Out:
#   countries_and_areas   latitude  longitude  oosr_pre0primary_age_male  \
# 0         Afghanistan  33.939110  67.709953                          0
# 1             Albania  41.153332  20.168331                          4
# 2             Algeria  28.033886   1.659626                          0
# 3             Andorra  42.506285   1.521801                          0
# 4              Angola  11.202692  17.873887                         31
#
#    oosr_pre0primary_age_female  oosr_primary_age_male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    oosr_primary_age_female  oosr_lower_secondary_age_male  \
# 0                        0                              0
# 1                        3                              6
# ...

# %%
df_clean_two.head()
# Out:
#   countries_and_areas   latitude  longitude  oosr_pre0primary_age_male  \
# 0         Afghanistan  33.939110  67.709953                          0
# 1             Albania  41.153332  20.168331                          4
# 2             Algeria  28.033886   1.659626                          0
# 3             Andorra  42.506285   1.521801                          0
# 4              Angola  11.202692  17.873887                         31
#
#    oosr_pre0primary_age_female  oosr_primary_age_male  \
# 0                            0                      0
# 1                            2                      6
# 2                            0                      0
# 3                            0                      0
# 4                           39                      0
#
#    oosr_primary_age_female  oosr_lower_secondary_age_male  \
# 0                        0                              0
# 1                        3                              6
# ...

# %%
first_row = df.iloc[0]
print(first_row)
# Out:
# countries_and_areas                        Afghanistan
# latitude                                      33.93911
# longitude                                    67.709953
# oosr_pre0primary_age_male                            0
# oosr_pre0primary_age_female                          0
# oosr_primary_age_male                                0
# oosr_primary_age_female                              0
# oosr_lower_secondary_age_male                        0
# oosr_lower_secondary_age_female                      0
# oosr_upper_secondary_age_male                       44
# oosr_upper_secondary_age_female                     69
# completion_rate_primary_male                        67
# completion_rate_primary_female                      40
# completion_rate_lower_secondary_male                49
# completion_rate_lower_secondary_female              26
# completion_rate_upper_secondary_male                32
# completion_rate_upper_secondary_female              14
# ...

# %%
# Type of Graph: Histogram
# A frequency distribution e.g. lots of countries/rows with with 0-6% unemployment rate and barely
# any with 25% unemployment
df['unemployment_rate'].hist()
# Out:
# <Axes: >

# %%
# Type of Graph: Boxplot
# Green line represents the median or midpoint
# Circles are outliers or data points outside the mininum or maximum bounds
# Bottom and Top lines are minimum and maximum data range
# Bottom of blue box is 25% percentile and top is 75% percentile
df.boxplot(column='unemployment_rate')
# Out:
# <Axes: >

# %%
# Correlation Matrix aka Heat map
# Shows us how correlated the values in any two columns are from [-1, 1]
# where values closer to -1 are not strongly correlated and values closer to 1 are strongly correlated
# E.g. If the value in unemployment rate column goes down how does that affect the birth_rate column
# does it make it go up or down or not affect it? this determines how correlated the columns are

import seaborn as sns

# correlation matrix depends on the values being numerical
df_numerical = df.select_dtypes(include=['number'])
correlation_matrix = df_numerical.corr()
correlation_matrix
# Out:
#                                          latitude  longitude  \
# latitude                                 1.000000  -0.296737
# longitude                               -0.296737   1.000000
# oosr_pre0primary_age_male               -0.251144  -0.099692
# oosr_pre0primary_age_female             -0.232117  -0.105877
# oosr_primary_age_male                   -0.256220  -0.142288
# oosr_primary_age_female                 -0.265878  -0.144630
# oosr_lower_secondary_age_male           -0.314519  -0.077958
# oosr_lower_secondary_age_female         -0.297764  -0.118649
# oosr_upper_secondary_age_male           -0.328922   0.024929
# oosr_upper_secondary_age_female         -0.319757  -0.049288
# completion_rate_primary_male            -0.197527  -0.004249
# completion_rate_primary_female          -0.199012   0.005703
# completion_rate_lower_secondary_male    -0.088137   0.023547
# completion_rate_lower_secondary_female  -0.076790   0.052954
# ...

# %%
# Create a heatmap using seaborn for a more user friendly correlation view
# A heatmap is basically just a visual version of the correlation matrix where it translates
# the correlation values for columns into colors which represent how correlated they are using the same
# correlation range of [-1, 1]
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >
